# %% [markdown]
# # **COVID-19 Data Analysis using Python 🦠📊**
#
# ## **Project Overview**
# This project focuses on analyzing **COVID-19 data** using Python. We use **Pandas, Matplotlib, and Seaborn** to explore the dataset, visualize trends, and derive insights.

# %%
# Import necessary libraries
import pandas as pd  # Data manipulation
import numpy as np  # Numerical operations
import matplotlib.pyplot as plt  # Data visualization
import seaborn as sns  # Statistical graphs

# %% [markdown]
# ## **🔹 Step 1: Load the Dataset**

# %%
# Load COVID-19 dataset
df = pd.read_csv('covid19_data.csv')
# Display first five rows
df.head()

# %% [markdown]
# ## **🔹 Step 2: Data Cleaning and Preprocessing**

# %%
# Checking for missing values
print(df.isnull().sum())

# Fill missing values with 0
df.fillna(0, inplace=True)

# %% [markdown]
# ## **🔹 Step 3: Exploratory Data Analysis (EDA)**

# %%
# Total Cases and Deaths per Country
top_countries = df.groupby('Country')[['Confirmed', 'Deaths']]
.sum().sort_values(by='Confirmed', ascending=False).head(10)
top_countries

# %%
# Visualizing Cases vs. Deaths
plt.figure(figsize=(10, 6))
sns.scatterplot(x=df['Confirmed'], y=df['Deaths'], alpha=0.5)
plt.xlabel('Total Confirmed Cases')
plt.ylabel('Total Deaths')
plt.title('COVID-19: Confirmed Cases vs Deaths')
plt.show()

# %% [markdown]
# ## **🔹 Step 4: Advanced Visualization**

# %%
# Heatmap of Case Correlations
plt.figure(figsize=(8,6))
sns.heatmap(df.corr(), annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()

# %% [markdown]
# ## **🔹 Conclusion**

# %% [markdown]
# - **Analyzed** COVID-19 dataset using Pandas.
# - **Visualized trends** in cases and deaths.
# - **Explored relationships** between confirmed cases and deaths.
# - **Identified top affected countries** and daily trends.
#
# 🚀 **This project provides insights into the COVID-19 pandemic using Python!**
